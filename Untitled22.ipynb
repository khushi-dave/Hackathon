# %%
import pandas as pd

# %%
dt = pd.read_csv('Surat.csv')
dt
# Out:
#      Sr. No.                                   NAME    CATEGORY  IMAGE  \
# 0        1.0                            Dumas Beach       Beach    NaN
# 1        2.0                           Suvali Beach       Beach    NaN
# 2        3.0                           Ubhrat Beach       Beach    NaN
# 3        4.0                    Rajhans Cinema Hall     Theatre    NaN
# 4        NaN                     PVR Rahul Raj Mall     Theatre    NaN
# ..       ...                                    ...         ...    ...
# 117      NaN                  Performing Art Centre  Auditorium    NaN
# 118      NaN           SARTHANA NATURE PARK AND ZOO         Zoo    NaN
# 119      NaN                     Elephanta Trirasto         Zoo    NaN
# 120      NaN                      Kisna Nature Park         Zoo    NaN
# 121      NaN  Jagdishchandra Bose Muncipal Aquarium         Zoo    NaN
#
#                                                ADDRESS  \
# 0    Dumas Rd, Sultanabad, Piplod, Surat, Gujarat 3...
# ...

# %%
dt.drop('IMAGE',axis=1,inplace=True)

# %%
dt.drop('Sr. No.',axis=1,inplace=True)

# %%
dt.shape
# Out:
# (122, 4)

# %%
dt
# Out:
#                                       NAME    CATEGORY  \
# 0                              Dumas Beach       Beach
# 1                             Suvali Beach       Beach
# 2                             Ubhrat Beach       Beach
# 3                      Rajhans Cinema Hall     Theatre
# 4                       PVR Rahul Raj Mall     Theatre
# ..                                     ...         ...
# 117                  Performing Art Centre  Auditorium
# 118           SARTHANA NATURE PARK AND ZOO         Zoo
# 119                     Elephanta Trirasto         Zoo
# 120                      Kisna Nature Park         Zoo
# 121  Jagdishchandra Bose Muncipal Aquarium         Zoo
#
#                                                ADDRESS  \
# 0    Dumas Rd, Sultanabad, Piplod, Surat, Gujarat 3...
# 1                                               Hajira
# 2                                    Ubhrat beach road
# 3    Pal Road Hazira, Road, opp. Rajhans Multiplex,...
# ...

# %%
dt.isnull().sum()
# Out:
# NAME        0
# CATEGORY    0
# ADDRESS     0
# LINK        0
# dtype: int64

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   NAME      122 non-null    object
#  1   CATEGORY  122 non-null    object
#  2   ADDRESS   122 non-null    object
#  3   LINK      122 non-null    object
# dtypes: object(4)
# memory usage: 3.9+ KB

# %%
dt.value_counts('CATEGORY')
# Out:
# CATEGORY
# Restaurants                  30
# Hotel                        25
# Theatre                      14
# Water Park/Amusement Park    14
# Mall                          6
# Temple                        6
# Auditorium                    5
# Church                        5
# Gurudwara                     5
# Mosque                        5
# Zoo                           4
# Beach                         3
# dtype: int64

# %%
brts = pd.read_csv('brts (1).csv')
brts
# Out:
#     Sr. No Route no.                         Route Name  \
# 0      1.0       112      Station To Palapur Jakat Naka
# 1      2.0       113      Station To Palapur Jakat Naka
# 2      3.0       115   St at ion To Jahangirpura Ashram
# 3      NaN     115-B            Station To Saroli Nal‹a
# 4      5.0     115-C     Station To Jahangirpura Ashram
# 5      6.0       121  Station To Veer Narmad University
# 6      7.0       122  Station To Veer Narmad University
# 7      8.0       123  Station To Veer Narmad University
# 8      9.0       125        Station To Rundh Jekat Naka
# 9     10.0     125-2        Station To Rundh Jakat Naka
# 10    11.0     127-1               Station To Bharthana
# 11    12.0     127-2               Station To Bharthana
# 12    13.0       128           Station To Bimpor Langar
# 13    14.0       129        Station To Dumas Nani Bazar
# 14    15.0     131-2   Station To Pandesara. Pani Tanki
# 15    16.0     131-3               Station To Pandesara
# ...

# %%
pref = input("Choose Your Preference: [from: Restaurants, Hotel, Theatre, Water Park/Amusement Park, Mall, Temple, Auditorium, Church, Beach, Gurudwara, Mosque, Zoo, Beach, Bus Service]")

if pref=='Restaurants':
  dt_Restaurants = dt[dt['CATEGORY'] == 'Restaurants']
  print(dt_Restaurants)

elif pref=='Hotel':
  dt_Hotel = dt[dt['CATEGORY'] == 'Hotel']
  print(dt_Hotel)

elif pref=='Theatre':
  dt_Theatre = dt[dt['CATEGORY'] == 'Theatre']
  print(dt_Theatre)

elif pref=='Water Park/Amusement Park':
  dt_Waterpark = dt[dt['CATEGORY'] == 'Water Park/Amusement Park']
  print(dt_Waterpark)

elif pref=='Mall':
  dt_Mall = dt[dt['CATEGORY'] == 'Mall']
  print(dt_Mall)

elif pref=='Temple':
  dt_Temple = dt[dt['CATEGORY'] == 'Temple']
  print(dt_Temple)

elif pref=='Auditorium':
  dt_Auditorium = dt[dt['CATEGORY'] == 'Auditorium']
  print(dt_Auditorium)

elif pref=='Church':
  dt_Church = dt[dt['CATEGORY'] == 'Church']
  print(dt_Church)

elif pref=='Beach':
  dt_beach = dt[dt['CATEGORY'] == 'Beach']
  print(dt_beach)

elif pref=='Gurudwara':
  dt_Gurudwara = dt[dt['CATEGORY'] == 'Gurudwara']
  print(dt_Gurudwara)

elif pref=='Mosque':
  dt_Mosque = dt[dt['CATEGORY'] == 'Mosque']
  print(dt_Mosque)

elif pref=='Zoo':
  dt_Zoo = dt[dt['CATEGORY'] == 'Zoo']
  print(dt_Zoo)

elif pref=='Beach':
  dt_Beach = dt[dt['CATEGORY'] == 'Beach']
  print(dt_Beach)

elif pref=='Bus Service':
  print(brts)

else:
  print("Sorry for the inconvinence!")
# Out:
# Choose Your Preference: [from: Restaurants, Hotel, Theatre, Water Park/Amusement Park, Mall, Temple, Auditorium, Church, Beach, Gurudwara, Mosque, Zoo, Beach, Bus Service]Bus Service
#     Sr. No Route no.                         Route Name  \
# 0      1.0       112      Station To Palapur Jakat Naka
# 1      2.0       113      Station To Palapur Jakat Naka
# 2      3.0       115   St at ion To Jahangirpura Ashram
# 3      NaN     115-B            Station To Saroli Nal‹a
# 4      5.0     115-C     Station To Jahangirpura Ashram
# 5      6.0       121  Station To Veer Narmad University
# 6      7.0       122  Station To Veer Narmad University
# 7      8.0       123  Station To Veer Narmad University
# 8      9.0       125        Station To Rundh Jekat Naka
# 9     10.0     125-2        Station To Rundh Jakat Naka
# 10    11.0     127-1               Station To Bharthana
# 11    12.0     127-2               Station To Bharthana
# 12    13.0       128           Station To Bimpor Langar
# ...
